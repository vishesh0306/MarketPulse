# %% [markdown]
# # MarketPulse — Exploratory Analysis
#
# Scratch space for ad-hoc exploration of processed tweets and generated signals.
# Not part of the pipeline; nothing here is imported by `src/`.
